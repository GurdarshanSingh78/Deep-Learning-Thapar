# %%
import numpy as np

X = np.array([
    [0, 0],
    [0, 1],
    [1, 0],
    [1, 1]
])

gates = {
    "AND":  np.array([0, 0, 0, 1]),
    "OR":   np.array([0, 1, 1, 1]),
    "NAND": np.array([1, 1, 1, 0]),
    "NOR":  np.array([1, 0, 0, 0]),
    "XOR":  np.array([0, 1, 1, 0])
}

print("Datasets initialized successfully!")
# Out:
# Datasets initialized successfully!

# %%
class Perceptron:
    def __init__(self, learning_rate=0.1, epochs=20):
        self.lr = learning_rate
        self.epochs = epochs
        self.weights = None
        self.bias = None

    def activation(self, x):
        return 1 if x >= 0 else 0

    def fit(self, X, y):
        n_samples, n_features = X.shape
        self.weights = np.zeros(n_features)
        self.bias = 0

        for epoch in range(self.epochs):
            for i in range(n_samples):
                linear_output = np.dot(X[i], self.weights) + self.bias
                y_pred = self.activation(linear_output)
                error = y[i] - y_pred
                self.weights += self.lr * error * X[i]
                self.bias += self.lr * error

    def predict(self, X):
        predictions = []
        for x in X:
            linear_output = np.dot(x, self.weights) + self.bias
            predictions.append(self.activation(linear_output))
        return predictions

# %%
for name, y in gates.items():
    print(f"\n========== Training {name} Gate ==========")

    model = Perceptron(learning_rate=0.1, epochs=20)
    model.fit(X, y)

    predictions = model.predict(X)

    print(f"Final Weights: {model.weights}")
    print(f"Final Bias: {model.bias:.2f}")
    print(f"Predictions:   {predictions}")
    print(f"Actual Targets: {y.tolist()}")

    if predictions == y.tolist():
        print("Learned Successfully")
    else:
        print("Not Learned (Expected for XOR)")
# Out:
# ========== Training AND Gate ==========
# Final Weights: [0.2 0.1]
# Final Bias: -0.20
# Predictions:   [0, 0, 0, 1]
# Actual Targets: [0, 0, 0, 1]
# Learned Successfully
#
# ========== Training OR Gate ==========
# Final Weights: [0.1 0.1]
# Final Bias: -0.10
# Predictions:   [0, 1, 1, 1]
# Actual Targets: [0, 1, 1, 1]
# Learned Successfully
#
# ========== Training NAND Gate ==========
# Final Weights: [-0.2 -0.1]
# Final Bias: 0.20
# Predictions:   [1, 1, 1, 0]
# Actual Targets: [1, 1, 1, 0]
# Learned Successfully
#
# ========== Training NOR Gate ==========
# Final Weights: [-0.1 -0.1]
# Final Bias: 0.00
# Predictions:   [1, 0, 0, 0]
# Actual Targets: [1, 0, 0, 0]
# Learned Successfully
#
# ========== Training XOR Gate ==========
# Final Weights: [-0.1  0. ]
# Final Bias: 0.00
# Predictions:   [1, 1, 0, 0]
# Actual Targets: [0, 1, 1, 0]
# Not Learned (Expected for XOR)
